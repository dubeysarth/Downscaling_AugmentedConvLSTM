# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import xarray as xr
import xesmf as xe
import netCDF4 as nc
import os

# %%
ds = xr.open_dataset(r"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/02_Raw_Data/IMD_Precipitation.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 43099, lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 1901-01-01 1901-01-02 ... 2018-12-31
# Data variables:
#     rain     (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2022-05-13 23:40:42.719111 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
ds = ds.sel(time=((ds.time.dt.year >= 1948) & (ds.time.dt.year <= 2005)))
ds = ds.sel(time=~((ds.time.dt.month == 2) & (ds.time.dt.day == 29)))
ds = ds.sel(time=~((ds.time.dt.month == 2) & (ds.time.dt.day == 30)))
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 21170, lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 1948-01-01 1948-01-02 ... 2005-12-31
# Data variables:
#     rain     (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2022-05-13 23:40:42.719111 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/IMD.nc")

# %%
dr = ds["rain"]
dr
# Out:
# <xarray.DataArray 'rain' (time: 21170, lat: 129, lon: 135)>
# [368675550 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 1948-01-01 1948-01-02 ... 2005-12-31
# Attributes:
#     units:      mm/day
#     long_name:  Rainfall

# %%
dr_np = dr.to_numpy()
dr_np.shape
# Out:
# (21170, 129, 135)

# %%
if min(dr_np.flatten()) < 0:
    dr_np[dr_np == min(dr_np.flatten())] = 0

# %%
np.save(
    r"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/npy_Files/IMD.npy", 
    dr_np
    )

# %%
def Process_360():
    ds = xr.open_dataset(r"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/02_Raw_Data/IMD_Precipitation.nc")
    ds = ds.sel(time=((ds.time.dt.year >= 1948) & (ds.time.dt.year <= 2005)))
    ds = ds.sel(time=~((ds.time.dt.month == 2) & (ds.time.dt.day == 29)))
    ds = ds.sel(time=~((ds.time.dt.month == 2) & (ds.time.dt.day == 30)))
    ds = ds.sel(time=~((ds.time.dt.day == 31)))
    ds = ds.sel(time=~((ds.time.dt.year == 2005) & (ds.time.dt.month == 12)))
    # ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/IMD.nc")
    dr = ds["rain"]
    dr_np = dr.to_numpy()
    print(dr_np.shape)
    if min(dr_np.flatten()) < 0:
        dr_np[dr_np == min(dr_np.flatten())] = 0
    np.save(
        r"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/npy_Files/IMD_360.npy", 
        dr_np
        )
        
Process_360()
# Out:
# (20734, 129, 135)
