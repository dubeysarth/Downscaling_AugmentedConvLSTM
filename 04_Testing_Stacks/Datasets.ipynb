# %%
import netCDF4 as nc
import pandas as pd
import numpy as np
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import os

from Testing_Stacks import *

# %%
lat_bnds, lon_bnds = [6.5, 38.5], [66.5, 100]
projection_dimension = [129, 135]
lat_lst = np.linspace(lat_bnds[0], lat_bnds[1], projection_dimension[0])
lon_lst = np.linspace(lon_bnds[0], lon_bnds[1], projection_dimension[1])

# %%
CanESM2 = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/CanESM2.nc")
HadGEM2_ES = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/HadGEM2-ES.nc")
MIROC_ESM = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/MIROC-ESM.nc")
GFDL_CM3 = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/GFDL-CM3.nc")

# %%
dates_CanESM2 = CanESM2.coords['time'].to_numpy()[4:]
dates_HadGEM2_ES = HadGEM2_ES.coords['time'].to_numpy()[4:]
dates_MIROC_ESM = MIROC_ESM.coords['time'].to_numpy()[4:]
dates_GFDL_CM3 = GFDL_CM3.coords['time'].to_numpy()[4:]
print(len(dates_CanESM2))
print(len(dates_HadGEM2_ES))
print(len(dates_MIROC_ESM))
print(len(dates_GFDL_CM3))
# Out:
# 21166
# 20730
# 21166
# 21166

# %%
print(dates_CanESM2.dtype)
print(dates_HadGEM2_ES.dtype)
print(dates_MIROC_ESM.dtype)
print(dates_GFDL_CM3.dtype)
# Out:
# object
# object
# datetime64[ns]
# object

# %%
dates_CanESM2[0]
# Out:
# cftime.DatetimeNoLeap(1948, 1, 5, 12, 0, 0, 0, has_year_zero=True)

# %%
dates_HadGEM2_ES[0]
# Out:
# cftime.Datetime360Day(1948, 1, 5, 12, 0, 0, 0, has_year_zero=True)

# %%
dates_MIROC_ESM[0]
# Out:
# numpy.datetime64('1948-01-05T12:00:00.000000000')

# %%
dates_GFDL_CM3[0]
# Out:
# cftime.DatetimeNoLeap(1948, 1, 5, 12, 0, 0, 0, has_year_zero=True)

# %%
model_name = 'MIROC-ESM'
pr_values = np.load(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/npy_Files/yy_hat_{model_name}.npy")
ds = xr.Dataset({
        'pr': xr.DataArray(
            data = pr_values.reshape(len(dates_MIROC_ESM), len(lat_lst), len(lon_lst)),
            dims = ['time', 'lat', 'lon'],
            coords = {
                'time': dates_MIROC_ESM,
                'lat': lat_lst,
                'lon': lon_lst
            },
            attrs = {'units':MIROC_ESM.pr.units}
        )
    }
)
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/NC_Files/{model_name}.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 21166, lat: 129, lon: 135)
# Coordinates:
#   * time     (time) datetime64[ns] 1948-01-05T12:00:00 ... 2005-12-31T12:00:00
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
# Data variables:
#     pr       (time, lat, lon) float32 0.04739 0.01377 ... -0.1466 0.02221

# %%
model_name = 'CanESM2'
pr_values = np.load(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/npy_Files/yy_hat_{model_name}.npy")
ds = xr.Dataset({
        'pr': xr.DataArray(
            data = pr_values.reshape(len(dates_CanESM2), len(lat_lst), len(lon_lst)),
            dims = ['time', 'lat', 'lon'],
            coords = {
                'time': dates_CanESM2,
                'lat': lat_lst,
                'lon': lon_lst
            },
            attrs = {'units':CanESM2.pr.units}
        )
    }
)
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/NC_Files/{model_name}.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 21166, lat: 129, lon: 135)
# Coordinates:
#   * time     (time) object 1948-01-05 12:00:00 ... 2005-12-31 12:00:00
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
# Data variables:
#     pr       (time, lat, lon) float32 0.09649 0.1336 ... -0.02689 0.04644

# %%
model_name = 'HadGEM2-ES'
pr_values = np.load(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/npy_Files/yy_hat_{model_name}.npy")
ds = xr.Dataset({
        'pr': xr.DataArray(
            data = pr_values.reshape(len(dates_HadGEM2_ES), len(lat_lst), len(lon_lst)),
            dims = ['time', 'lat', 'lon'],
            coords = {
                'time': dates_HadGEM2_ES,
                'lat': lat_lst,
                'lon': lon_lst
            },
            attrs = {'units':HadGEM2_ES.pr.units}
        )
    }
)
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/NC_Files/{model_name}.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 20730, lat: 129, lon: 135)
# Coordinates:
#   * time     (time) object 1948-01-05 12:00:00 ... 2005-11-30 12:00:00
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
# Data variables:
#     pr       (time, lat, lon) float32 1.005 1.536 1.801 ... -0.4795 -0.4215

# %%
model_name = 'GFDL-CM3'
pr_values = np.load(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/npy_Files/yy_hat_{model_name}.npy")
ds = xr.Dataset({
        'pr': xr.DataArray(
            data = pr_values.reshape(len(dates_GFDL_CM3), len(lat_lst), len(lon_lst)),
            dims = ['time', 'lat', 'lon'],
            coords = {
                'time': dates_GFDL_CM3,
                'lat': lat_lst,
                'lon': lon_lst
            },
            attrs = {'units':GFDL_CM3.pr.units}
        )
    }
)
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/NC_Files/{model_name}.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 21166, lat: 129, lon: 135)
# Coordinates:
#   * time     (time) object 1948-01-05 12:00:00 ... 2005-12-31 12:00:00
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
# Data variables:
#     pr       (time, lat, lon) float32 1.124 1.702 1.874 ... -0.06887 0.0472
