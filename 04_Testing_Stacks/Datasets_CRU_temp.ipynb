# %%
import netCDF4 as nc
import pandas as pd
import numpy as np
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import os

# %%
lat_bnds, lon_bnds = [25, 50], [-125, -70]
lat_lst = np.arange(lat_bnds[0], lat_bnds[1]+0.01, 0.5)
lon_lst = np.arange(lon_bnds[0], lon_bnds[1]+0.01, 0.5)
print(lat_lst[1]-lat_lst[0], lon_lst[1]-lon_lst[0])
print(len(lat_lst), len(lon_lst))
projection_dimension = [129, 135]
# Out:
# 0.5 0.5
# 51 111

# %%
CanESM2 = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/CanESM2_mon_temp.nc")
# HadGEM2_ES = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/HadGEM2-ES_mon_temp.nc")
MIROC_ESM = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/MIROC-ESM_mon_temp.nc")
GFDL_CM3 = xr.open_dataset("/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/03_Preprocess_Data/NC_Files/GFDL-CM3_mon_temp.nc")

# %%
dates_CanESM2 = CanESM2.coords['time'].to_numpy()[4:]
# dates_HadGEM2_ES = HadGEM2_ES.coords['time'].to_numpy()[4:]
dates_MIROC_ESM = MIROC_ESM.coords['time'].to_numpy()[4:]
dates_GFDL_CM3 = GFDL_CM3.coords['time'].to_numpy()[4:]
print(len(dates_CanESM2))
# print(len(dates_HadGEM2_ES))
print(len(dates_MIROC_ESM))
print(len(dates_GFDL_CM3))
# Out:
# 692
# 692
# 692

# %%
model_name = 'MIROC-ESM'
pr_values = np.load(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/npy_Files/yy_hat_{model_name}_mon_temp.npy")
pr_values = np.array(pr_values[:,39:90,12:123,:])
ds = xr.Dataset({
        'tas': xr.DataArray(
            data = pr_values.reshape(len(dates_MIROC_ESM), len(lat_lst), len(lon_lst)),
            dims = ['time', 'lat', 'lon'],
            coords = {
                'time': dates_MIROC_ESM,
                'lat': lat_lst,
                'lon': [x%360 for x in lon_lst]
            },
            attrs = {'units':MIROC_ESM.tas.units}
        )
    }
)
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/NC_Files/{model_name}_mon_temp.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 692, lat: 51, lon: 111)
# Coordinates:
#   * time     (time) datetime64[ns] 1948-05-16T12:00:00 ... 2005-12-16T12:00:00
#   * lat      (lat) float64 25.0 25.5 26.0 26.5 27.0 ... 48.0 48.5 49.0 49.5 50.0
#   * lon      (lon) float64 235.0 235.5 236.0 236.5 ... 288.5 289.0 289.5 290.0
# Data variables:
#     tas      (time, lat, lon) float32 -0.0438 2.071 2.839 ... -0.02614 -0.01454

# %%
model_name = 'CanESM2'
pr_values = np.load(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/npy_Files/yy_hat_{model_name}_mon_temp.npy")
pr_values = np.array(pr_values[:,39:90,12:123,:])
ds = xr.Dataset({
        'tas': xr.DataArray(
            data = pr_values.reshape(len(dates_CanESM2), len(lat_lst), len(lon_lst)),
            dims = ['time', 'lat', 'lon'],
            coords = {
                'time': dates_CanESM2,
                'lat': lat_lst,
                'lon': [x%360 for x in lon_lst]
            },
            attrs = {'units':CanESM2.tas.units}
        )
    }
)
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/NC_Files/{model_name}_mon_temp.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 692, lat: 51, lon: 111)
# Coordinates:
#   * time     (time) object 1948-05-16 12:00:00 ... 2005-12-16 12:00:00
#   * lat      (lat) float64 25.0 25.5 26.0 26.5 27.0 ... 48.0 48.5 49.0 49.5 50.0
#   * lon      (lon) float64 235.0 235.5 236.0 236.5 ... 288.5 289.0 289.5 290.0
# Data variables:
#     tas      (time, lat, lon) float32 -0.03679 2.064 2.843 ... -0.01906 -0.01124

# %%
model_name = 'GFDL-CM3'
pr_values = np.load(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/npy_Files/yy_hat_{model_name}_mon_temp.npy")
pr_values = np.array(pr_values[:,39:90,12:123,:])
ds = xr.Dataset({
        'tas': xr.DataArray(
            data = pr_values.reshape(len(dates_GFDL_CM3), len(lat_lst), len(lon_lst)),
            dims = ['time', 'lat', 'lon'],
            coords = {
                'time': dates_GFDL_CM3,
                'lat': lat_lst,
                'lon': [x%360 for x in lon_lst]
            },
            attrs = {'units':GFDL_CM3.tas.units}
        )
    }
)
ds.to_netcdf(rf"/home/uditbhatia/Documents/Sarth/Downscaling_AugmentedConvLSTM/04_Testing_Stacks/NC_Files/{model_name}_mon_temp.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 692, lat: 51, lon: 111)
# Coordinates:
#   * time     (time) object 1948-05-16 12:00:00 ... 2005-12-16 12:00:00
#   * lat      (lat) float64 25.0 25.5 26.0 26.5 27.0 ... 48.0 48.5 49.0 49.5 50.0
#   * lon      (lon) float64 235.0 235.5 236.0 236.5 ... 288.5 289.0 289.5 290.0
# Data variables:
#     tas      (time, lat, lon) float32 0.699 1.328 2.325 ... -0.001632 -0.06689
